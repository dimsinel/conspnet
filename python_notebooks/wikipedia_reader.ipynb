# %%
import wikipedia, wikipediaapi
import networkx as nx
#import pandas as pd
import pickle

# %%
# %run WikiFunctions.py

# %%
# just an empty oblect
a= wikiItem()
a.print()
# Out:
# node name: None
# wiki name: None
# tag1:      None

# %%
with open("objList_file.pickle", "rb") as f:
    objList = pickle.load(f)

# %%
objList[1].wikiSummary
# Out:
# 'In the United States, abolitionism, the movement that sought to end slavery in the country, was active from the late colonial era until the American Civil War, the end of which brought about the abolition of American slavery for non-criminals through the Thirteenth Amendment to the United States Constitution (ratified 1865).\nThe anti-slavery movement originated during the Age of Enlightenment, focused on ending the trans-Atlantic slave trade. In Colonial America, a few German Quakers issued the 1688 Germantown Quaker Petition Against Slavery, which marks the beginning of the American abolitionist movement. Before the Revolutionary War, evangelical colonists were the primary advocates for the opposition to slavery and the slave trade, doing so on humanitarian grounds. James Oglethorpe, the founder of the colony of Georgia, originally tried to prohibit slavery upon its founding in 1735 under the Georgia Experiment, a decision that was eventually reversed in 1750.During the Revolution
# ...

# %%
for ob in objList:
    print(f'{ob.nodeName}')
# Out:
# AIDS
# Abolitionism
# Abortion
# African Americans
# Agent Orange
# Alien and Sedition Acts
# American Indian Movement
# American Protective Association
# American Revolution
# Anarchists
# Anti-Catholicism
# Anti-Federalists
# Anti-Masonic Party
# Anticommunism
# Antisemitism
# Apocalypticism
# Area 51
# Arnold, Benedict
# Aryan Nations
# Asian Americans
# Atomic Secrets
# Aurora
# Bacon's Rebellion
# Banco Nazionale del Lavoro
# Bank War
# Bank of Credit and Commerce International
# Bank of England
# Bank of the United States
# Barruel, Abbé
# Bay of Pigs Invasion
# Beam, Louis
# Bell, Art
# Berg, Alan
# Biddle, Nicholas
# Bilderbergers
# Black Helicopters
# Black Panthers
# Booth, John Wilkes
# Boston Massacre
# Boston Tea Party
# British Royal Family
# Brown Scare
# Brown, John
# Brussell, Mae
# Bryan, William Jennings
# Bureau of Alcohol, Tobacco, and Firearms
# Burr, Aaron
# Burroughs, William S.
# Bush, George
# COINTELPRO
# Cambodia, Secret Bombing of
# Castro, Fidel
# ...

# %%
for ob in objList:
    ob.print()
    print()
# Out:
# node name: AIDS
# wiki name: AIDS
# tag1:      conspiracy theory
#
# node name: Abolitionism
# wiki name: Abolitionism in the United States
# tag1:      movement
#
# node name: Abortion
# wiki name: Abortion in the United States
# tag1:      politics
#
# node name: African Americans
# wiki name: African Americans
# tag1:      movement
#
# node name: Agent Orange
# wiki name: Agent Orange
# tag1:      weapon
# tag2:      conspiracy theory
#
# node name: Alien and Sedition Acts
# wiki name: Alien and Sedition Acts
# tag1:      politics
#
# node name: American Indian Movement
# wiki name: American Indian Movement
# tag1:      movement
#
# node name: American Protective Association
# wiki name: American Protective Association
# tag1:      organization
#
# node name: American Revolution
# wiki name: American Revolution
# tag1:      politics
# tag2:      event
#
# node name: Anarchists
# wiki name: Anarchists
# tag1:      philosophy
#
# node name: Anti-Catholicism
# ...

# %%
a = findByWikiName("kennedy", objList)
if a.nodeName != None:
    a.print()
# Out:
# Multiple entries found
# node name: Kennedy, John F., Assassination of
# wiki name: John F. Kennedy assassination conspiracy theories
# tag1:      person
# tag2:      politics
# node name: Kennedy, Robert F., Assassination of
# wiki name: Robert F. Kennedy assassination conspiracy theories
# tag1:      person
# tag2:      politics

# %%
# Now try by node name
a = findByNodeName("reagan", objList)
a.print()
# Out:
# node name: Reagan, Ronald, Attempted Assassination of
# wiki name: Attempted assassination of Ronald Reagan
# tag1:      person
# tag2:      politics

# %%
wikiItem(None).print()
# Out:
# node name: None
# wiki name: None
# tag1:      None
